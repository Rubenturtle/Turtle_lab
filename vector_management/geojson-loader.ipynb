# %%
import geopandas as gpd
import json


df = gpd.read_file(r"C:\Users\ruben.crespo\Downloads\merged_blue_spots_smoothed_rp_20_2030.geojson")
# df.to_json('C:/Users/ruben.crespo/Documents/02_Ruben_scripts/Python_codigo/turtle_lab/vector_management/geojson_lloader.json', orient='records')

# %%
df.to_file("big_data.gpkg", driver='GPKG')  # Save as Parquet

# %%
# Then next time:
gdf = gpd.read_parquet("big_data.parquet")

# %%
df.columns
# Out:
# Index(['level_0', 'level_1', 'geometry'], dtype='object')

# %%
df.head()
# Out:
#    level_0  level_1                                           geometry
# 0      0.0      0.0  POLYGON ((-0.20858 39.64298, -0.20858 39.64298...
# 1      0.0      0.0  POLYGON ((-0.20862 39.64308, -0.20861 39.64309...
# 2      0.0      0.0  POLYGON ((-0.21004 39.64334, -0.21004 39.64334...
# 3      0.0      0.0  POLYGON ((-0.20891 39.64375, -0.20891 39.64375...
# 4      0.0      0.0  POLYGON ((-0.20920 39.64401, -0.20919 39.64401...
