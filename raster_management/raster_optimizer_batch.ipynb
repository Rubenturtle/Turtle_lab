# %% [markdown]
# # Raster optimizer
# - We want to import some rasters inside and make them all full optimized
# - Here we cover all the possible issues we could get from a raster layer
# - The process gives an optimized raster as an output

# %%
"""This script goes for every tif file in a folder"""

import os
import sys
from sys import path
from osgeo import gdal
from numpy import random
import numpy as np
import time

# %%
"""input and output"""
path = r"C:\Users\admin\Downloads\wetlands"
output_path = path + "\output"

# %%
def get_raster_file_list(path):
    """Get a list of the raster files inside the folder"""
    File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
    for file in os.listdir(path):
        if file.endswith(".tif") or file.endswith(".tiff"):
            if file not in File_list:
                File_list.append(os.path.join(path,file))
        else:
            pass
    return File_list

def create_output_folder(output_path):
    """Create the output folder"""
    if not os.path.exists(output_path):
        print("created the output folder")    
        return os.mkdir(output_path)
    else:
        return print("there is already an output folder")

# %%
def get_optimal_dtype(raster_path, block_size=1024):
    # Open the raster dataset
    dataset = gdal.Open(raster_path)
    if dataset is None:
        raise ValueError("Unable to open the raster file.")

    # Get raster properties
    num_cols = dataset.RasterXSize
    num_rows = dataset.RasterYSize
    num_bands = dataset.RasterCount

    # Analyze the range of values and determine the optimal data type
    min_val = None
    max_val = None

    for y in range(0, num_rows, block_size):
        rows = min(block_size, num_rows - y)
        for x in range(0, num_cols, block_size):
            cols = min(block_size, num_cols - x)

            # Read a block of raster data
            block_data = dataset.ReadAsArray(x, y, cols, rows)

            # Get unique values and update min_val and max_val
            unique_values = np.unique(block_data)
            if min_val is None:
                min_val = np.min(unique_values)
                max_val = np.max(unique_values)
            else:
                min_val = min(min_val, np.min(unique_values))
                max_val = max(max_val, np.max(unique_values))

    dtype = None

    if np.issubdtype(block_data.dtype, np.integer):
        if min_val >= 0:
            if max_val <= 255:
                dtype = gdal.GDT_Byte
            elif max_val <= 65535:
                dtype = gdal.GDT_UInt16
            else:
                dtype = gdal.GDT_Int32
        else:
            if min_val >= -32768 and max_val <= 32767:
                dtype = gdal.GDT_Int16
            else:
                dtype = gdal.GDT_Int32
    else:
        # Floating-point data
        dtype = gdal.GDT_Float32

    return dtype

def convert_data_type(input_raster, output_raster, data_type):
    # Open the input raster dataset
    dataset = gdal.Open(input_raster)
    if dataset is None:
        raise ValueError("Unable to open the input raster file.")
    
    if not data_type:
        print("Get the data type")
        band = dataset.GetRasterBand(1)
        data_type = band.DataType

    # get the projection
    projection = dataset.GetProjection()

    # Create the output raster dataset with the desired data type
    gdal.Warp(output_raster, 
              dataset, 
              outputType=data_type, 
              dstSRS=projection, 
              dstNodata=0, 
              creationOptions = ["TILED=YES","COMPRESS=DEFLATE",'COPY_SRC_OVERVIEWS=YES'])

    # Close the datasets
    dataset = None
    return print("finished with: " + output_raster)

# %%
File_list = get_raster_file_list(path)
print(File_list)
create_output_folder(output_path)

rule = "don't calculate optimal type" # Habrá que mejorar esto

for file in File_list[:]:
    print(file)
    # get the file name
    filename = os.path.basename(file)
    # split the filename by the dot and add a sufix
    output_filename = os.path.splitext(filename)[0] + ".tif"
    #build the output path + new filename
    output_file = os.path.join(output_path,output_filename)
    # get the optimal file type
    if not rule:
        dtype = get_optimal_dtype(file)
        convert_data_type(file, output_file, dtype)
        
    print("no need to optimize")
    convert_data_type(file, output_file, data_type=None)
    
print("Raster data type optimization completed.")
# Out:
# ['C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N10.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N15.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N20.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N35.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N40.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N45.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N50.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N55.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E0N65.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N0.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N10.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N15.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N20.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N25.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N30.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N35.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N40.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N45.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N5.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N50.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N55.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N60.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N65.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N70.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N75.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100N80.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E100S5.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N0.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N10.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N15.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N20.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N25.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N30.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N35.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N40.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N45.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N5.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N50.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N55.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N60.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N65.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N70.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N75.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105N80.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E105S5.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N0.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N10.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N15.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N20.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N30.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N35.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N40.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N45.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N5.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N50.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N55.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N60.tif', 'C:\\Users\\admin\\Downloads\\wetlands\\GWL_FCS30_2020_E10N65.tif', 'C:\\Users\\admin\\Downloads\\wetlan ...
# created the output folder
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E0N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E0N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E100S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E100S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E105S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E105S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E10S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E10S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E110S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E110S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E115S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E115S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E120S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E120S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E125S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E125S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E130S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E130S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E135S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E135S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E140S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E140S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E145S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E145S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E150S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E150S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E155S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E155S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E15N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E15N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E15N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E15N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E15N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E15N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E15N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_E15N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_E15N25.tif
# ...
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W75S55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W75S55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W80S50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W80S50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W85S5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W85S5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N10.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N10.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W90N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W90N80.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N0.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N0.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N15.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N15.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N20.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N20.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N25.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N25.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N30.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N30.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N35.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N35.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N40.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N40.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N45.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N45.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N5.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N5.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N50.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N50.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N55.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N55.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N60.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N60.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N65.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N65.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N70.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N70.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N75.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N75.tif
# C:\Users\admin\Downloads\wetlands\GWL_FCS30_2020_W95N80.tif
# no need to optimize
# Get the data type
# finished with: C:\Users\admin\Downloads\wetlands\output\GWL_FCS30_2020_W95N80.tif
# Raster data type optimization completed.

# %%
"""Create the overviews if neccesary"""
File_list = get_raster_file_list(output_path)

for file in File_list[:]:
    # Open the raster dataset
    dataset = gdal.Open(file, gdal.GA_Update) # GA_Update is used when we want to do modification on the raster

    if dataset:
        # Get the first raster band (assuming single-band raster)
        band = dataset.GetRasterBand(1)

        # Check if the band has overviews
        if band.GetOverviewCount() > 0:
            print("Raster band already has overviews.")
        else:
            # Build overviews using multiple overview levels (2x, 4x, 8x, etc.)
            overview_levels = [2, 4, 8]
            dataset.BuildOverviews("average", overview_levels)
            print("Overviews built successfully.")

        dataset = None  # Close the dataset
    else:
        print("Failed to open the dataset.")

# %% [markdown]
# Some personal testing

# %%
os.chdir(path)

#This iterates for every file in the directory
for file in File_list[:]:
    print(file)
    dataset = gdal.Open(file)

    """This part is just for testing, it is not really neccesary of this case.
     This is a way to get the Metadata of the raster (If the raster is big It can take more than 2mins)"""
    stats =  dataset.GetRasterBand(1).GetStatistics(0,1) #it will return a list(Min, Max, Mean, StdDev)
    Metadata_domain = dataset.GetMetadataDomainList() #From here we get the 'IMAGE_STRUCTURE'
    image_structure = dataset.GetMetadata('IMAGE_STRUCTURE') #here inside

    """The file is too big to read it into a single array, so we are going to split into different ones"""

    """Here we get the size of the file"""
    width = dataset.RasterXSize #columns
    height = dataset.RasterYSize #rows

    # define your tile size
    # it could be 256,512 or 1024. it depends on your scope
    tilesize = 10000

    unique_values_list = []

    """Here we start with the tiling to"""
    for i in range(0, width, tilesize)[0:1]: #tilesize marks from where to where in width
        w = min(i+tilesize, width) - i
        for j in range(0, height, tilesize)[0:1]: #tilesize in height
            #for the edge parts, so we don't get nodata from the borders
            h = min(j+tilesize, height) - j
            try:
                ds = gdal.Translate("",
                dataset, 
                format = 'MEM', 
                # noData = -32768,
                # outputType = gdal.GDT_Int16, 
                # creationOptions = ['COMPRESS=DEFLATE','TILED=YES','COPY_SRC_OVERVIEWS=YES'],
                srcWin = [str(i), str(j), str(w), str(h)])
                print("the dataset is: ", ds)

                band =  ds.GetRasterBand(1)
                array = np.array(band.ReadAsArray())
                values = np.unique(array)
                for x in values:
                    print (x)
                    if x not in unique_values_list:
                        unique_values_list.append(x)
                    else:
                        pass
                ds = None
            except RuntimeError:
                print("The script got an error")
                sys.exit(1)

# %%
"""
Tenemos que comprobar que los datos sean Categoricos o contiugos
Para categoricos habria que hacer el vecino proximo
Para continuos habría que hacerlo Bicubica - Bilineal
"""


#This iterates for every file in the directory
for file in os.listdir(path)[0:1]:
    #un landcover al ser una classificacion tendra valores tipo int (NearestNeightbour), los valores tipo real son mas para elevaciones, distancias etc (bilineal)

    # resampleAlg = gdal.GRIORA_NearestNeighbour
    # resampleAlg = gdal.GRIORA_Bilinear
    # esto añadelo al final

    #we concatenate the path
    input = path +"/"+ file
    output = out + '/' + file.replace(".tif","") + "_optimized.tif"
    #here is the GDAL transformation, we set the path + / + variable
    
    # gdal.Warp(output, input, creationOptions = ['COMPRESS=' + str(compression)], dstSRS = "EPSG:4326")
    gdal.Translate(output, input, creationOptions = ['COMPRESS=DEFLATE','TILED=YES','BLOCKXSIZE=128','BLOCKYSIZE=128'])
    

    ds = gdal.Open(output, 1)
    band = ds.GetRasterBand(1)
    band.SetRasterColorTable(None) # this works and deletes the color pallete
    # band.DestroyColorTable() #another option

    #set the data type


    del band, ds
        
    else:
        pass

print("It's over the optimization")
# Out:
# It's over the optimization
