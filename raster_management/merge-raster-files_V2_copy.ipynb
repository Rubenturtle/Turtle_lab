# %%
from osgeo import gdal
import os

# %%
"""Take the folders in case there is more than one folder"""
# main_path = r"C:/Users/admin/Downloads/intact_forest"
# main_path = r"//akif.internal/public/z_resources/ruben/wb_temporal/cstorage_gabon2020"
# main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge"
main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge_2\automatic_merge"
os.chdir(main_path)
Folder_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
for file in os.listdir(main_path): # [1:]
    if os.path.isdir(file):
        if file not in Folder_list:
            Folder_list.append(os.path.join(main_path, file).replace("\\","/"))
    else:
        pass

print(Folder_list[:])
# Out:
# ['Z:/veg_c_storage_rawdata/testing/to_merge_2/automatic_merge/2015_1', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/automatic_merge/2016_1', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/automatic_merge/2017_1']

# %%
"""In case there is only one folder"""
# main_path = r"C:/Users/admin/Downloads/drive-download-20230605T205149Z-001"
# # main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge\second_merge\2010_1"
main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge_2\2014_1"
os.chdir(main_path)
# Folder_list = ["Z:/z_resources/im-wb/results/cstorage_gabon2002_second_try"]
Folder_list = [main_path]
print(Folder_list[:])
# Out:
# ['Z:\\veg_c_storage_rawdata\\testing\\to_merge_2\\2014_1']

# %%
"""check if it takes all files"""
for folder in Folder_list[:]: #[:]
    File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
    for file in os.listdir(folder):
        if file.endswith(".tiff") or file.endswith(".tif"):
            if file not in File_list:
                File_list.append(os.path.join(folder, file).replace("\\","/"))
print(File_list)
# Out:
# ['Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5525.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5935.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4642.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6941.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3189.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6285.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4124.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5573.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3236.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4986.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6831.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2903.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4520.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4063.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2324.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4400.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1832.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2795.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2520.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2852.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1708.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2450.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4169.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2919.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4923.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4127.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5940.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4304.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3208.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3396.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1487.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4517.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3468.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2785.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6949.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6621.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2860.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1750.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5823.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3806.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2530.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_5724.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4622.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1868.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1482.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3652.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3318.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4725.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6820.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_2250.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4293.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1324.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_6068.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3421.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_4084.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3220.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_3560.tiff', 'Z:/veg_c_storage_rawdata/testing/to_merge_2/2014_1/tile_1478.tiff ...

# %%
"""
- Get a list of the raster files inside the folder.
- Do the geoprocessing per each file"""

for folder in Folder_list[:]: #[:]
    File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
    for file in os.listdir(folder):
        if file.endswith(".tiff") or file.endswith(".tif"):
            if file not in File_list:
                File_list.append(os.path.join(folder, file).replace("\\","/"))
        else:
            pass
    output = os.path.basename(folder) + "_merged.tif" #if the output is the name of the folder
    # output = "vcs_2020_global_300m_1.tif"

    # Specify the desired pixel size in the output
    x_resolution = 0.002777777777777777884  # Horizontal pixel size
    y_resolution = 0.002777777777777777884  # Vertical pixel size

    """Geoprocessing"""
    merged_tif = gdal.Warp(output, File_list, format="GTiff",
            #   outputType = gdal.GDT_Byte, # this thing converts nodata values to zeros
              # srcNodata = -32768, # gives a value to the nodata areas
            #   srcWin = [str(180), str(84), str(-180), str(-57)]
            xRes=x_resolution, yRes=y_resolution,
            dstNodata = -32768, # sets the no data value
            creationOptions=["COMPRESS=DEFLATE", "TILED=YES"])
    
    """remove the color pallete""" #optional         
    # band = merged_tif.GetRasterBand(1)
    # band.SetRasterColorTable(None)
    # # Close file and flush to disk
    # del band

    merged_tif = None 
    print(output)
# Out:
# 2015_1_merged.tif
# 2016_1_merged.tif
# 2017_1_merged.tif

# %%
"""File parser / For testing"""

path = r"Z:\z_resources\ruben\utci_2021\raster_output"
File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
for file in os.listdir(path): 
    if ".tif" in file:
        if file not in File_list:
            # File_list.append(os.path.join(path, file).replace("\\","/"))
            File_list.append(file)
    else:
        pass
    
    file_string = " ".join(File_list)
    print(file_string)

# %%
os.chdir(path)
text_file = open("sample.txt", "w")
n = text_file.write(file_string)
text_file.close()

# %%
print(os.getcwd())
# Out:
# \\akif.internal\public\z_resources\ruben\wb_temporal\cstorage_gabon2020
