# %%
from osgeo import gdal
import os

# %%
"""Take the folders in case there is more than one folder"""
# main_path = r"C:/Users/admin/Downloads/intact_forest"
# main_path = r"//akif.internal/public/z_resources/ruben/wb_temporal/cstorage_gabon2020"
# main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge"
main_path = r"Z:\veg_c_storage_rawdata\testing\merge"
os.chdir(main_path)
Folder_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
for file in os.listdir(main_path): # [1:]
    if os.path.isdir(file):
        if file not in Folder_list:
            Folder_list.append(os.path.join(main_path, file).replace("\\","/"))
    else:
        pass
print(Folder_list[:10])
# Out:
# ['Z:/veg_c_storage_rawdata/testing/merge/2010_1', 'Z:/veg_c_storage_rawdata/testing/merge/2011_1', 'Z:/veg_c_storage_rawdata/testing/merge/2012_1', 'Z:/veg_c_storage_rawdata/testing/merge/2013_1', 'Z:/veg_c_storage_rawdata/testing/merge/2014_1', 'Z:/veg_c_storage_rawdata/testing/merge/2015_1', 'Z:/veg_c_storage_rawdata/testing/merge/2016_1', 'Z:/veg_c_storage_rawdata/testing/merge/2017_1', 'Z:/veg_c_storage_rawdata/testing/merge/2018_1', 'Z:/veg_c_storage_rawdata/testing/merge/2019_1']

# %%
"""In case there is only one folder"""
# main_path = r"C:/Users/admin/Downloads/drive-download-20230605T205149Z-001"
# # main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge\second_merge\2010_1"
main_path = r"Z:\veg_c_storage_rawdata\testing\to_merge\autoprocess\2015_1"
os.chdir(main_path)
# Folder_list = ["Z:/z_resources/im-wb/results/cstorage_gabon2002_second_try"]
Folder_list = [main_path]
print(Folder_list[:])
# Out:
# ['Z:\\veg_c_storage_rawdata\\testing\\to_merge\\autoprocess\\2015_1']

# %%
"""check if it takes all files"""
for folder in Folder_list[:]: #[:]
    File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
    for file in os.listdir(folder):
        if file.endswith(".tiff") or file.endswith(".tif"):
            if file not in File_list:
                File_list.append(os.path.join(folder, file).replace("\\","/"))
print(File_list)
# Out:
# ['Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2010_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2011_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2012_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2013_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2014_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2015_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2016_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2017_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2018_global_300m_merged.tif', 'Z:/veg_c_storage_rawdata/testing/merge/v1_merge/vcs_2019_global_300m_merged.tif']

# %%
"""
- Get a list of the raster files inside the folder.
- Do the geoprocessing per each file
"""
#beware if the folder indexation is okay
for folder in Folder_list[:10]: #[:]
    print("starting: " + folder)
    File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
    for file in os.listdir(folder):
        if file.endswith(".tiff") or file.endswith(".tif"):
            if file not in File_list:
                File_list.append(os.path.join(folder, file).replace("\\","/"))
        else:
            pass
    output = os.path.basename(folder) + "_merged_total_v2.tif" #if the output is the name of the folder
    # output = "vcs_2020_global_300m_1.tif"

    # Specify the desired pixel size in the output
    x_resolution = 0.002777777777777777884  # Horizontal pixel size
    y_resolution = 0.002777777777777777884  # Vertical pixel size

    """Geoprocessing"""
    merged_tif = gdal.Warp(output, File_list, format="GTiff",
            #   outputType = gdal.GDT_Byte, # this thing converts nodata values to zeros
              # srcNodata = -32768, # gives a value to the nodata areas
            #   srcWin = [str(180), str(84), str(-180), str(-57)]
            xRes=x_resolution, yRes=y_resolution,
            dstNodata = -32768, # sets the no data value
            creationOptions=["COMPRESS=DEFLATE", "TILED=YES"])
    
    """remove the color pallete""" #optional         
    # band = merged_tif.GetRasterBand(1)
    # band.SetRasterColorTable(None)
    # # Close file and flush to disk
    # del band

    merged_tif = None 
    print(output)
# Out:
# starting: Z:/veg_c_storage_rawdata/testing/merge/2010_1
# 2010_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2011_1
# 2011_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2012_1
# 2012_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2013_1
# 2013_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2014_1
# 2014_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2015_1
# 2015_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2016_1
# 2016_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2017_1
# 2017_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2018_1
# 2018_1_merged_total_v2.tif
# starting: Z:/veg_c_storage_rawdata/testing/merge/2019_1
# 2019_1_merged_total_v2.tif

# %%
"""File parser / For testing"""

path = r"Z:\z_resources\ruben\utci_2021\raster_output"
File_list = [] #f for f in os.listdir(path) if os.isfile(mypath,f)
for file in os.listdir(path): 
    if ".tif" in file:
        if file not in File_list:
            # File_list.append(os.path.join(path, file).replace("\\","/"))
            File_list.append(file)
    else:
        pass
    
    file_string = " ".join(File_list)
    print(file_string)

# %%
os.chdir(path)
text_file = open("sample.txt", "w")
n = text_file.write(file_string)
text_file.close()

# %%
print(os.getcwd())
# Out:
# \\akif.internal\public\z_resources\ruben\wb_temporal\cstorage_gabon2020
